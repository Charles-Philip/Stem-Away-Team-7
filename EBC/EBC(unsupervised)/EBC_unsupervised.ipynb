# %%
# !git clone https://github.com/blpercha/ebc.git
# Out:
# Cloning into 'ebc'...
# remote: Enumerating objects: 324, done.
# remote: Total 324 (delta 0), reused 0 (delta 0), pack-reused 324
# Receiving objects: 100% (324/324), 1.42 MiB | 21.72 MiB/s, done.
# Resolving deltas: 100% (183/183), done.

# %%
import sys
sys.path.insert(0,'/content/ebc')

# %%
from ebc import EBC
from matrix import SparseMatrix
import pandas as pd
import numpy as np

# %%
#Creating a zero matrix according to the number of drug-gene pairs 
mat = np.zeros([3514, 3514], dtype = int)
print(mat[0][0])
# Out:
# 0

# %%
with open("/content/ebc/resources/matrix-ebc-paper-dense.tsv", "r") as f:
        data = []
        for line in f:
            sl = line.split("\t")
            if len(sl) < 5:  # headers
                continue
            data.append([sl[0], sl[2], float(sl[4])])

matrix = SparseMatrix([3514, 1232])
matrix.read_data(data)
matrix.normalize()
# print(matrix)
ebc = EBC(matrix, [30, 125], 10, 1e-10, 0.01)

#Running EBC 1000 times
for k in range(1000):
    cXY, objective, it = ebc.run()
    #only taking the drug-gene pair cluster as cXY[0] corresponds to that and cXY[1] corresponds to dependency path clusters
    for i in range(len(cXY[0])):
        for j in range(len(cXY[0])):
            #Checking if pair[i] is assigned to the same cluster as pair[j]
            if (cXY[0][i] == cXY[0][j]):
                #Incrementing the count at that position
                mat[i][j] = mat[i][j] + 1
                
print(mat)
# Out:
# Streaming output truncated to the last 5000 lines.
# --> Running iteration 1 .. objective value = 3.571478
# --> Running iteration 2 .. objective value = 3.522732
# --> Running iteration 3 .. objective value = 3.508818
# --> Running iteration 4 .. objective value = 3.502224
# EBC finished in 4 iterations, with final objective value 3.5022
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.473585
# --> Running iteration 2 .. objective value = 3.433978
# --> Running iteration 3 .. objective value = 3.424722
# EBC finished in 3 iterations, with final objective value 3.4247
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.492894
# --> Running iteration 2 .. objective value = 3.430550
# --> Running iteration 3 .. objective value = 3.418593
# --> Running iteration 4 .. objective value = 3.412544
# EBC finished in 4 iterations, with final objective value 3.4125
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.472450
# --> Running iteration 2 .. objective value = 3.432251
# --> Running iteration 3 .. objective value = 3.415735
# --> Running iteration 4 .. objective value = 3.410602
# EBC finished in 4 iterations, with final objective value 3.4106
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.516089
# --> Running iteration 2 .. objective value = 3.465363
# --> Running iteration 3 .. objective value = 3.450842
# --> Running iteration 4 .. objective value = 3.446983
# EBC finished in 4 iterations, with final objective value 3.4470
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.483626
# --> Running iteration 2 .. objective value = 3.433197
# --> Running iteration 3 .. objective value = 3.421240
# --> Running iteration 4 .. objective value = 3.413779
# EBC finished in 4 iterations, with final objective value 3.4138
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.467641
# --> Running iteration 2 .. objective value = 3.411468
# --> Running iteration 3 .. objective value = 3.394369
# --> Running iteration 4 .. objective value = 3.387965
# EBC finished in 4 iterations, with final objective value 3.3880
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.413253
# --> Running iteration 2 .. objective value = 3.373539
# --> Running iteration 3 .. objective value = 3.364584
# EBC finished in 3 iterations, with final objective value 3.3646
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.386068
# --> Running iteration 2 .. objective value = 3.332523
# --> Running iteration 3 .. objective value = 3.322319
# --> Running iteration 4 .. objective value = 3.318284
# EBC finished in 4 iterations, with final objective value 3.3183
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.455061
# --> Running iteration 2 .. objective value = 3.406112
# --> Running iteration 3 .. objective value = 3.388855
# --> Running iteration 4 .. objective value = 3.379784
# EBC finished in 4 iterations, with final objective value 3.3798
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.403464
# --> Running iteration 2 .. objective value = 3.355390
# --> Running iteration 3 .. objective value = 3.340521
# --> Running iteration 4 .. objective value = 3.334218
# EBC finished in 4 iterations, with final objective value 3.3342
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.477741
# --> Running iteration 2 .. objective value = 3.426746
# --> Running iteration 3 .. objective value = 3.411251
# --> Running iteration 4 .. objective value = 3.405777
# EBC finished in 4 iterations, with final objective value 3.4058
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.444613
# --> Running iteration 2 .. objective value = 3.395673
# --> Running iteration 3 .. objective value = 3.379851
# --> Running iteration 4 .. objective value = 3.372664
# EBC finished in 4 iterations, with final objective value 3.3727
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.419934
# --> Running iteration 2 .. objective value = 3.372226
# --> Running iteration 3 .. objective value = 3.350549
# --> Running iteration 4 .. objective value = 3.345357
# EBC finished in 4 iterations, with final objective value 3.3454
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.470748
# --> Running iteration 2 .. objective value = 3.411051
# --> Running iteration 3 .. objective value = 3.393625
# --> Running iteration 4 .. objective value = 3.388155
# EBC finished in 4 iterations, with final objective value 3.3882
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.419659
# --> Running iteration 2 .. objective value = 3.376083
# --> Running iteration 3 .. objective value = 3.364085
# --> Running iteration 4 .. objective value = 3.357206
# EBC finished in 4 iterations, with final objective value 3.3572
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.507882
# --> Running iteration 2 .. objective value = 3.451931
# --> Running iteration 3 .. objective value = 3.436533
# --> Running iteration 4 .. objective value = 3.432609
# EBC finished in 4 iterations, with final objective value 3.4326
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.454986
# --> Running iteration 2 .. objective value = 3.398522
# --> Running iteration 3 .. objective value = 3.385900
# --> Running iteration 4 .. objective value = 3.380925
# EBC finished in 4 iterations, with final objective value 3.3809
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.474539
# --> Running iteration 2 .. objective value = 3.418528
# --> Running iteration 3 .. objective value = 3.404954
# --> Running iteration 4 .. objective value = 3.401235
# EBC finished in 4 iterations, with final objective value 3.4012
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.366179
# --> Running iteration 2 .. objective value = 3.316260
# --> Running iteration 3 .. objective value = 3.306815
# EBC finished in 3 iterations, with final objective value 3.3068
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.483777
# --> Running iteration 2 .. objective value = 3.426828
# --> Running iteration 3 .. objective value = 3.412260
# --> Running iteration 4 .. objective value = 3.407461
# EBC finished in 4 iterations, with final objective value 3.4075
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.430506
# --> Running iteration 2 .. objective value = 3.377943
# --> Running iteration 3 .. objective value = 3.365555
# --> Running iteration 4 .. objective value = 3.356818
# EBC finished in 4 iterations, with final objective value 3.3568
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.542741
# --> Running iteration 2 .. objective value = 3.493602
# --> Running iteration 3 .. objective value = 3.483647
# EBC finished in 3 iterations, with final objective value 3.4836
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.439170
# --> Running iteration 2 .. objective value = 3.378106
# --> Running iteration 3 .. objective value = 3.360395
# --> Running iteration 4 .. objective value = 3.353613
# EBC finished in 4 iterations, with final objective value 3.3536
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.433237
# --> Running iteration 2 .. objective value = 3.383595
# --> Running iteration 3 .. objective value = 3.374072
# EBC finished in 3 iterations, with final objective value 3.3741
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.492334
# --> Running iteration 2 .. objective value = 3.436665
# --> Running iteration 3 .. objective value = 3.426277
# --> Running iteration 4 .. objective value = 3.421047
# EBC finished in 4 iterations, with final objective value 3.4210
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.458681
# --> Running iteration 2 .. objective value = 3.408564
# --> Running iteration 3 .. objective value = 3.398183
# --> Running iteration 4 .. objective value = 3.393351
# EBC finished in 4 iterations, with final objective value 3.3934
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.465167
# --> Running iteration 2 .. objective value = 3.417143
# --> Running iteration 3 .. objective value = 3.405219
# --> Running iteration 4 .. objective value = 3.401300
# EBC finished in 4 iterations, with final objective value 3.4013
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.365877
# --> Running iteration 2 .. objective value = 3.324293
# --> Running iteration 3 .. objective value = 3.312341
# --> Running iteration 4 .. objective value = 3.309218
# EBC finished in 4 iterations, with final objective value 3.3092
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.463375
# --> Running iteration 2 .. objective value = 3.420987
# --> Running iteration 3 .. objective value = 3.413161
# EBC finished in 3 iterations, with final objective value 3.4132
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.554254
# --> Running iteration 2 .. objective value = 3.485968
# --> Running iteration 3 .. objective value = 3.469822
# --> Running iteration 4 .. objective value = 3.466763
# EBC finished in 4 iterations, with final objective value 3.4668
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.418298
# --> Running iteration 2 .. objective value = 3.359642
# --> Running iteration 3 .. objective value = 3.340209
# --> Running iteration 4 .. objective value = 3.336506
# EBC finished in 4 iterations, with final objective value 3.3365
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.475052
# --> Running iteration 2 .. objective value = 3.424201
# --> Running iteration 3 .. objective value = 3.412212
# --> Running iteration 4 .. objective value = 3.409903
# EBC finished in 4 iterations, with final objective value 3.4099
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.466700
# --> Running iteration 2 .. objective value = 3.402359
# --> Running iteration 3 .. objective value = 3.384827
# --> Running iteration 4 .. objective value = 3.378471
# EBC finished in 4 iterations, with final objective value 3.3785
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.508221
# --> Running iteration 2 .. objective value = 3.449966
# --> Running iteration 3 .. objective value = 3.434375
# --> Running iteration 4 .. objective value = 3.429528
# EBC finished in 4 iterations, with final objective value 3.4295
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.466775
# --> Running iteration 2 .. objective value = 3.413624
# --> Running iteration 3 .. objective value = 3.395466
# --> Running iteration 4 .. objective value = 3.384750
# --> Running iteration 5 .. objective value = 3.381798
# EBC finished in 5 iterations, with final objective value 3.3818
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.445934
# --> Running iteration 2 .. objective value = 3.402439
# --> Running iteration 3 .. objective value = 3.390027
# --> Running iteration 4 .. objective value = 3.386245
# EBC finished in 4 iterations, with final objective value 3.3862
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.488815
# --> Running iteration 2 .. objective value = 3.442097
# --> Running iteration 3 .. objective value = 3.427098
# --> Running iteration 4 .. objective value = 3.415836
# --> Running iteration 5 .. objective value = 3.411431
# EBC finished in 5 iterations, with final objective value 3.4114
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.408116
# --> Running iteration 2 .. objective value = 3.347458
# --> Running iteration 3 .. objective value = 3.326922
# --> Running iteration 4 .. objective value = 3.315132
# --> Running iteration 5 .. objective value = 3.312350
# EBC finished in 5 iterations, with final objective value 3.3123
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.461413
# --> Running iteration 2 .. objective value = 3.416021
# --> Running iteration 3 .. objective value = 3.405057
# --> Running iteration 4 .. objective value = 3.399135
# EBC finished in 4 iterations, with final objective value 3.3991
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.437182
# --> Running iteration 2 .. objective value = 3.387386
# --> Running iteration 3 .. objective value = 3.375738
# --> Running iteration 4 .. objective value = 3.371861
# EBC finished in 4 iterations, with final objective value 3.3719
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.563112
# --> Running iteration 2 .. objective value = 3.497998
# --> Running iteration 3 .. objective value = 3.485223
# --> Running iteration 4 .. objective value = 3.480247
# EBC finished in 4 iterations, with final objective value 3.4802
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.443422
# --> Running iteration 2 .. objective value = 3.392756
# --> Running iteration 3 .. objective value = 3.380445
# --> Running iteration 4 .. objective value = 3.374346
# EBC finished in 4 iterations, with final objective value 3.3743
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.419731
# --> Running iteration 2 .. objective value = 3.368529
# --> Running iteration 3 .. objective value = 3.355628
# --> Running iteration 4 .. objective value = 3.351902
# EBC finished in 4 iterations, with final objective value 3.3519
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.515585
# --> Running iteration 2 .. objective value = 3.463242
# --> Running iteration 3 .. objective value = 3.449825
# --> Running iteration 4 .. objective value = 3.443446
# EBC finished in 4 iterations, with final objective value 3.4434
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.495867
# --> Running iteration 2 .. objective value = 3.455997
# --> Running iteration 3 .. objective value = 3.440363
# --> Running iteration 4 .. objective value = 3.434980
# EBC finished in 4 iterations, with final objective value 3.4350
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.457975
# --> Running iteration 2 .. objective value = 3.407305
# --> Running iteration 3 .. objective value = 3.392212
# --> Running iteration 4 .. objective value = 3.385477
# EBC finished in 4 iterations, with final objective value 3.3855
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.444457
# --> Running iteration 2 .. objective value = 3.395518
# --> Running iteration 3 .. objective value = 3.383017
# --> Running iteration 4 .. objective value = 3.377661
# EBC finished in 4 iterations, with final objective value 3.3777
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.522636
# --> Running iteration 2 .. objective value = 3.467411
# --> Running iteration 3 .. objective value = 3.454751
# --> Running iteration 4 .. objective value = 3.447302
# EBC finished in 4 iterations, with final objective value 3.4473
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.424717
# --> Running iteration 2 .. objective value = 3.374712
# --> Running iteration 3 .. objective value = 3.363054
# --> Running iteration 4 .. objective value = 3.357827
# EBC finished in 4 iterations, with final objective value 3.3578
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.474980
# --> Running iteration 2 .. objective value = 3.432278
# --> Running iteration 3 .. objective value = 3.420173
# --> Running iteration 4 .. objective value = 3.413472
# EBC finished in 4 iterations, with final objective value 3.4135
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.447789
# --> Running iteration 2 .. objective value = 3.395484
# --> Running iteration 3 .. objective value = 3.382080
# --> Running iteration 4 .. objective value = 3.377848
# EBC finished in 4 iterations, with final objective value 3.3778
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.463731
# --> Running iteration 2 .. objective value = 3.410982
# --> Running iteration 3 .. objective value = 3.396691
# --> Running iteration 4 .. objective value = 3.391142
# EBC finished in 4 iterations, with final objective value 3.3911
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.435448
# --> Running iteration 2 .. objective value = 3.400094
# --> Running iteration 3 .. objective value = 3.389579
# --> Running iteration 4 .. objective value = 3.387617
# EBC finished in 4 iterations, with final objective value 3.3876
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.453160
# --> Running iteration 2 .. objective value = 3.401882
# --> Running iteration 3 .. objective value = 3.392197
# EBC finished in 3 iterations, with final objective value 3.3922
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.452563
# --> Running iteration 2 .. objective value = 3.414368
# --> Running iteration 3 .. objective value = 3.404164
# --> Running iteration 4 .. objective value = 3.399345
# EBC finished in 4 iterations, with final objective value 3.3993
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.507447
# --> Running iteration 2 .. objective value = 3.453798
# --> Running iteration 3 .. objective value = 3.443948
# EBC finished in 3 iterations, with final objective value 3.4439
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.484616
# --> Running iteration 2 .. objective value = 3.433312
# --> Running iteration 3 .. objective value = 3.419438
# --> Running iteration 4 .. objective value = 3.415595
# EBC finished in 4 iterations, with final objective value 3.4156
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.436931
# --> Running iteration 2 .. objective value = 3.366495
# --> Running iteration 3 .. objective value = 3.352645
# --> Running iteration 4 .. objective value = 3.348709
# EBC finished in 4 iterations, with final objective value 3.3487
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.455264
# --> Running iteration 2 .. objective value = 3.408406
# --> Running iteration 3 .. objective value = 3.392999
# --> Running iteration 4 .. objective value = 3.385748
# EBC finished in 4 iterations, with final objective value 3.3857
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.441663
# --> Running iteration 2 .. objective value = 3.386891
# --> Running iteration 3 .. objective value = 3.376721
# --> Running iteration 4 .. objective value = 3.366699
# --> Running iteration 5 .. objective value = 3.363484
# EBC finished in 5 iterations, with final objective value 3.3635
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.397506
# --> Running iteration 2 .. objective value = 3.348304
# --> Running iteration 3 .. objective value = 3.332440
# --> Running iteration 4 .. objective value = 3.328234
# EBC finished in 4 iterations, with final objective value 3.3282
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.472233
# --> Running iteration 2 .. objective value = 3.434324
# --> Running iteration 3 .. objective value = 3.425583
# EBC finished in 3 iterations, with final objective value 3.4256
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.421960
# --> Running iteration 2 .. objective value = 3.380519
# --> Running iteration 3 .. objective value = 3.370364
# --> Running iteration 4 .. objective value = 3.366790
# EBC finished in 4 iterations, with final objective value 3.3668
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.422380
# --> Running iteration 2 .. objective value = 3.366710
# --> Running iteration 3 .. objective value = 3.351587
# --> Running iteration 4 .. objective value = 3.345440
# EBC finished in 4 iterations, with final objective value 3.3454
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.387298
# --> Running iteration 2 .. objective value = 3.337844
# --> Running iteration 3 .. objective value = 3.324929
# --> Running iteration 4 .. objective value = 3.319460
# EBC finished in 4 iterations, with final objective value 3.3195
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.444298
# --> Running iteration 2 .. objective value = 3.386396
# --> Running iteration 3 .. objective value = 3.370984
# --> Running iteration 4 .. objective value = 3.366564
# EBC finished in 4 iterations, with final objective value 3.3666
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.450792
# --> Running iteration 2 .. objective value = 3.397138
# --> Running iteration 3 .. objective value = 3.386291
# --> Running iteration 4 .. objective value = 3.383361
# EBC finished in 4 iterations, with final objective value 3.3834
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.452489
# --> Running iteration 2 .. objective value = 3.411785
# --> Running iteration 3 .. objective value = 3.399670
# --> Running iteration 4 .. objective value = 3.395230
# EBC finished in 4 iterations, with final objective value 3.3952
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.445994
# --> Running iteration 2 .. objective value = 3.402894
# --> Running iteration 3 .. objective value = 3.392799
# --> Running iteration 4 .. objective value = 3.386743
# EBC finished in 4 iterations, with final objective value 3.3867
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.487556
# --> Running iteration 2 .. objective value = 3.433418
# --> Running iteration 3 .. objective value = 3.419310
# --> Running iteration 4 .. objective value = 3.412123
# EBC finished in 4 iterations, with final objective value 3.4121
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.373453
# --> Running iteration 2 .. objective value = 3.328183
# --> Running iteration 3 .. objective value = 3.317153
# --> Running iteration 4 .. objective value = 3.310123
# EBC finished in 4 iterations, with final objective value 3.3101
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.468374
# --> Running iteration 2 .. objective value = 3.422492
# --> Running iteration 3 .. objective value = 3.410445
# --> Running iteration 4 .. objective value = 3.407979
# EBC finished in 4 iterations, with final objective value 3.4080
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.480893
# --> Running iteration 2 .. objective value = 3.434429
# --> Running iteration 3 .. objective value = 3.421457
# --> Running iteration 4 .. objective value = 3.417919
# EBC finished in 4 iterations, with final objective value 3.4179
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.464944
# --> Running iteration 2 .. objective value = 3.409611
# --> Running iteration 3 .. objective value = 3.400443
# EBC finished in 3 iterations, with final objective value 3.4004
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.458997
# --> Running iteration 2 .. objective value = 3.412987
# --> Running iteration 3 .. objective value = 3.399564
# --> Running iteration 4 .. objective value = 3.392236
# EBC finished in 4 iterations, with final objective value 3.3922
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.428511
# --> Running iteration 2 .. objective value = 3.372323
# --> Running iteration 3 .. objective value = 3.354348
# --> Running iteration 4 .. objective value = 3.349047
# EBC finished in 4 iterations, with final objective value 3.3490
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.462201
# --> Running iteration 2 .. objective value = 3.391655
# --> Running iteration 3 .. objective value = 3.370493
# --> Running iteration 4 .. objective value = 3.359370
# --> Running iteration 5 .. objective value = 3.351353
# EBC finished in 5 iterations, with final objective value 3.3514
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.464828
# --> Running iteration 2 .. objective value = 3.408048
# --> Running iteration 3 .. objective value = 3.395250
# --> Running iteration 4 .. objective value = 3.391620
# EBC finished in 4 iterations, with final objective value 3.3916
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.477427
# --> Running iteration 2 .. objective value = 3.428421
# --> Running iteration 3 .. objective value = 3.412880
# --> Running iteration 4 .. objective value = 3.408150
# EBC finished in 4 iterations, with final objective value 3.4081
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.534561
# --> Running iteration 2 .. objective value = 3.476378
# --> Running iteration 3 .. objective value = 3.463338
# --> Running iteration 4 .. objective value = 3.457577
# EBC finished in 4 iterations, with final objective value 3.4576
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.430775
# --> Running iteration 2 .. objective value = 3.364649
# --> Running iteration 3 .. objective value = 3.350932
# --> Running iteration 4 .. objective value = 3.347609
# EBC finished in 4 iterations, with final objective value 3.3476
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.395134
# --> Running iteration 2 .. objective value = 3.350576
# --> Running iteration 3 .. objective value = 3.336537
# --> Running iteration 4 .. objective value = 3.328174
# EBC finished in 4 iterations, with final objective value 3.3282
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.421237
# --> Running iteration 2 .. objective value = 3.371760
# --> Running iteration 3 .. objective value = 3.358962
# --> Running iteration 4 .. objective value = 3.354739
# EBC finished in 4 iterations, with final objective value 3.3547
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.500024
# --> Running iteration 2 .. objective value = 3.455719
# --> Running iteration 3 .. objective value = 3.445162
# --> Running iteration 4 .. objective value = 3.438498
# EBC finished in 4 iterations, with final objective value 3.4385
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.448785
# --> Running iteration 2 .. objective value = 3.393738
# --> Running iteration 3 .. objective value = 3.376801
# --> Running iteration 4 .. objective value = 3.370712
# EBC finished in 4 iterations, with final objective value 3.3707
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.470362
# --> Running iteration 2 .. objective value = 3.424839
# --> Running iteration 3 .. objective value = 3.412576
# --> Running iteration 4 .. objective value = 3.409141
# EBC finished in 4 iterations, with final objective value 3.4091
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.409564
# --> Running iteration 2 .. objective value = 3.357614
# --> Running iteration 3 .. objective value = 3.343374
# --> Running iteration 4 .. objective value = 3.339685
# EBC finished in 4 iterations, with final objective value 3.3397
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.509805
# --> Running iteration 2 .. objective value = 3.452578
# --> Running iteration 3 .. objective value = 3.438797
# --> Running iteration 4 .. objective value = 3.433380
# EBC finished in 4 iterations, with final objective value 3.4334
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.381035
# --> Running iteration 2 .. objective value = 3.331276
# --> Running iteration 3 .. objective value = 3.317628
# --> Running iteration 4 .. objective value = 3.313570
# EBC finished in 4 iterations, with final objective value 3.3136
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.473872
# --> Running iteration 2 .. objective value = 3.429673
# --> Running iteration 3 .. objective value = 3.417579
# --> Running iteration 4 .. objective value = 3.409485
# EBC finished in 4 iterations, with final objective value 3.4095
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.480385
# --> Running iteration 2 .. objective value = 3.422036
# --> Running iteration 3 .. objective value = 3.403319
# --> Running iteration 4 .. objective value = 3.397306
# EBC finished in 4 iterations, with final objective value 3.3973
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.401079
# --> Running iteration 2 .. objective value = 3.343093
# --> Running iteration 3 .. objective value = 3.330514
# --> Running iteration 4 .. objective value = 3.324574
# EBC finished in 4 iterations, with final objective value 3.3246
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.397356
# --> Running iteration 2 .. objective value = 3.343695
# --> Running iteration 3 .. objective value = 3.330254
# --> Running iteration 4 .. objective value = 3.325938
# EBC finished in 4 iterations, with final objective value 3.3259
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.465964
# --> Running iteration 2 .. objective value = 3.425695
# --> Running iteration 3 .. objective value = 3.414273
# --> Running iteration 4 .. objective value = 3.410177
# EBC finished in 4 iterations, with final objective value 3.4102
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.501349
# --> Running iteration 2 .. objective value = 3.455183
# --> Running iteration 3 .. objective value = 3.441782
# --> Running iteration 4 .. objective value = 3.439325
# EBC finished in 4 iterations, with final objective value 3.4393
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.490574
# --> Running iteration 2 .. objective value = 3.432923
# --> Running iteration 3 .. objective value = 3.419798
# --> Running iteration 4 .. objective value = 3.413717
# EBC finished in 4 iterations, with final objective value 3.4137
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.451339
# --> Running iteration 2 .. objective value = 3.402506
# --> Running iteration 3 .. objective value = 3.389631
# --> Running iteration 4 .. objective value = 3.384617
# EBC finished in 4 iterations, with final objective value 3.3846
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.393660
# --> Running iteration 2 .. objective value = 3.347247
# --> Running iteration 3 .. objective value = 3.342191
# EBC finished in 3 iterations, with final objective value 3.3422
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.425888
# --> Running iteration 2 .. objective value = 3.372618
# --> Running iteration 3 .. objective value = 3.361422
# --> Running iteration 4 .. objective value = 3.355470
# EBC finished in 4 iterations, with final objective value 3.3555
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.480883
# --> Running iteration 2 .. objective value = 3.429090
# --> Running iteration 3 .. objective value = 3.418590
# --> Running iteration 4 .. objective value = 3.414072
# EBC finished in 4 iterations, with final objective value 3.4141
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.425081
# --> Running iteration 2 .. objective value = 3.380132
# --> Running iteration 3 .. objective value = 3.371184
# EBC finished in 3 iterations, with final objective value 3.3712
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.485988
# --> Running iteration 2 .. objective value = 3.430138
# --> Running iteration 3 .. objective value = 3.417927
# --> Running iteration 4 .. objective value = 3.414482
# EBC finished in 4 iterations, with final objective value 3.4145
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.535796
# --> Running iteration 2 .. objective value = 3.478817
# --> Running iteration 3 .. objective value = 3.461729
# --> Running iteration 4 .. objective value = 3.453777
# EBC finished in 4 iterations, with final objective value 3.4538
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.421061
# --> Running iteration 2 .. objective value = 3.370887
# --> Running iteration 3 .. objective value = 3.355881
# --> Running iteration 4 .. objective value = 3.352338
# EBC finished in 4 iterations, with final objective value 3.3523
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.435927
# --> Running iteration 2 .. objective value = 3.381654
# --> Running iteration 3 .. objective value = 3.363780
# --> Running iteration 4 .. objective value = 3.357452
# EBC finished in 4 iterations, with final objective value 3.3575
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.494617
# --> Running iteration 2 .. objective value = 3.445982
# --> Running iteration 3 .. objective value = 3.435747
# --> Running iteration 4 .. objective value = 3.432171
# EBC finished in 4 iterations, with final objective value 3.4322
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.403243
# --> Running iteration 2 .. objective value = 3.356524
# --> Running iteration 3 .. objective value = 3.345936
# --> Running iteration 4 .. objective value = 3.340419
# EBC finished in 4 iterations, with final objective value 3.3404
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.520162
# --> Running iteration 2 .. objective value = 3.462348
# --> Running iteration 3 .. objective value = 3.448098
# --> Running iteration 4 .. objective value = 3.444695
# EBC finished in 4 iterations, with final objective value 3.4447
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.448139
# --> Running iteration 2 .. objective value = 3.403960
# --> Running iteration 3 .. objective value = 3.393058
# --> Running iteration 4 .. objective value = 3.389272
# EBC finished in 4 iterations, with final objective value 3.3893
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.442977
# --> Running iteration 2 .. objective value = 3.377631
# --> Running iteration 3 .. objective value = 3.364009
# --> Running iteration 4 .. objective value = 3.360998
# EBC finished in 4 iterations, with final objective value 3.3610
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.450314
# --> Running iteration 2 .. objective value = 3.386772
# --> Running iteration 3 .. objective value = 3.370000
# --> Running iteration 4 .. objective value = 3.364706
# EBC finished in 4 iterations, with final objective value 3.3647
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.433303
# --> Running iteration 2 .. objective value = 3.395187
# --> Running iteration 3 .. objective value = 3.386009
# EBC finished in 3 iterations, with final objective value 3.3860
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.463940
# --> Running iteration 2 .. objective value = 3.403459
# --> Running iteration 3 .. objective value = 3.382868
# --> Running iteration 4 .. objective value = 3.376840
# EBC finished in 4 iterations, with final objective value 3.3768
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.400110
# --> Running iteration 2 .. objective value = 3.356237
# --> Running iteration 3 .. objective value = 3.348163
# EBC finished in 3 iterations, with final objective value 3.3482
# ...
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.418495
# --> Running iteration 2 .. objective value = 3.363323
# --> Running iteration 3 .. objective value = 3.337449
# --> Running iteration 4 .. objective value = 3.331585
# EBC finished in 4 iterations, with final objective value 3.3316
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.445391
# --> Running iteration 2 .. objective value = 3.396234
# --> Running iteration 3 .. objective value = 3.383438
# --> Running iteration 4 .. objective value = 3.377080
# EBC finished in 4 iterations, with final objective value 3.3771
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.445605
# --> Running iteration 2 .. objective value = 3.392824
# --> Running iteration 3 .. objective value = 3.376947
# --> Running iteration 4 .. objective value = 3.372579
# EBC finished in 4 iterations, with final objective value 3.3726
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.454780
# --> Running iteration 2 .. objective value = 3.407239
# --> Running iteration 3 .. objective value = 3.397983
# EBC finished in 3 iterations, with final objective value 3.3980
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.437747
# --> Running iteration 2 .. objective value = 3.384079
# --> Running iteration 3 .. objective value = 3.367833
# --> Running iteration 4 .. objective value = 3.361631
# EBC finished in 4 iterations, with final objective value 3.3616
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.400821
# --> Running iteration 2 .. objective value = 3.360737
# --> Running iteration 3 .. objective value = 3.349051
# --> Running iteration 4 .. objective value = 3.345258
# EBC finished in 4 iterations, with final objective value 3.3453
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.533211
# --> Running iteration 2 .. objective value = 3.471362
# --> Running iteration 3 .. objective value = 3.447188
# --> Running iteration 4 .. objective value = 3.440886
# EBC finished in 4 iterations, with final objective value 3.4409
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.492295
# --> Running iteration 2 .. objective value = 3.426122
# --> Running iteration 3 .. objective value = 3.404426
# --> Running iteration 4 .. objective value = 3.398494
# EBC finished in 4 iterations, with final objective value 3.3985
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.431970
# --> Running iteration 2 .. objective value = 3.375839
# --> Running iteration 3 .. objective value = 3.358896
# --> Running iteration 4 .. objective value = 3.352924
# EBC finished in 4 iterations, with final objective value 3.3529
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.403205
# --> Running iteration 2 .. objective value = 3.362166
# --> Running iteration 3 .. objective value = 3.348558
# --> Running iteration 4 .. objective value = 3.341650
# EBC finished in 4 iterations, with final objective value 3.3416
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.433739
# --> Running iteration 2 .. objective value = 3.379951
# --> Running iteration 3 .. objective value = 3.362676
# --> Running iteration 4 .. objective value = 3.357219
# EBC finished in 4 iterations, with final objective value 3.3572
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.447579
# --> Running iteration 2 .. objective value = 3.392207
# --> Running iteration 3 .. objective value = 3.377407
# --> Running iteration 4 .. objective value = 3.370564
# EBC finished in 4 iterations, with final objective value 3.3706
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.412820
# --> Running iteration 2 .. objective value = 3.357173
# --> Running iteration 3 .. objective value = 3.342337
# --> Running iteration 4 .. objective value = 3.334702
# EBC finished in 4 iterations, with final objective value 3.3347
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.452956
# --> Running iteration 2 .. objective value = 3.396972
# --> Running iteration 3 .. objective value = 3.379118
# --> Running iteration 4 .. objective value = 3.374306
# EBC finished in 4 iterations, with final objective value 3.3743
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.533072
# --> Running iteration 2 .. objective value = 3.481457
# --> Running iteration 3 .. objective value = 3.471308
# --> Running iteration 4 .. objective value = 3.467836
# EBC finished in 4 iterations, with final objective value 3.4678
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.398807
# --> Running iteration 2 .. objective value = 3.351660
# --> Running iteration 3 .. objective value = 3.338803
# --> Running iteration 4 .. objective value = 3.334791
# EBC finished in 4 iterations, with final objective value 3.3348
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.451398
# --> Running iteration 2 .. objective value = 3.403170
# --> Running iteration 3 .. objective value = 3.392718
# --> Running iteration 4 .. objective value = 3.388571
# EBC finished in 4 iterations, with final objective value 3.3886
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.429198
# --> Running iteration 2 .. objective value = 3.378880
# --> Running iteration 3 .. objective value = 3.360076
# --> Running iteration 4 .. objective value = 3.355322
# EBC finished in 4 iterations, with final objective value 3.3553
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.406127
# --> Running iteration 2 .. objective value = 3.357353
# --> Running iteration 3 .. objective value = 3.347575
# EBC finished in 3 iterations, with final objective value 3.3476
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.575884
# --> Running iteration 2 .. objective value = 3.529801
# --> Running iteration 3 .. objective value = 3.520622
# EBC finished in 3 iterations, with final objective value 3.5206
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.439282
# --> Running iteration 2 .. objective value = 3.379181
# --> Running iteration 3 .. objective value = 3.360898
# --> Running iteration 4 .. objective value = 3.355056
# EBC finished in 4 iterations, with final objective value 3.3551
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.524505
# --> Running iteration 2 .. objective value = 3.471132
# --> Running iteration 3 .. objective value = 3.456303
# --> Running iteration 4 .. objective value = 3.451938
# EBC finished in 4 iterations, with final objective value 3.4519
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.498063
# --> Running iteration 2 .. objective value = 3.441451
# --> Running iteration 3 .. objective value = 3.428816
# --> Running iteration 4 .. objective value = 3.427432
# EBC finished in 4 iterations, with final objective value 3.4274
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.444192
# --> Running iteration 2 .. objective value = 3.401476
# --> Running iteration 3 .. objective value = 3.389444
# --> Running iteration 4 .. objective value = 3.385727
# EBC finished in 4 iterations, with final objective value 3.3857
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.479216
# --> Running iteration 2 .. objective value = 3.429748
# --> Running iteration 3 .. objective value = 3.417623
# --> Running iteration 4 .. objective value = 3.410763
# EBC finished in 4 iterations, with final objective value 3.4108
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.480571
# --> Running iteration 2 .. objective value = 3.423895
# --> Running iteration 3 .. objective value = 3.410422
# --> Running iteration 4 .. objective value = 3.405023
# EBC finished in 4 iterations, with final objective value 3.4050
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.449549
# --> Running iteration 2 .. objective value = 3.399189
# --> Running iteration 3 .. objective value = 3.388747
# --> Running iteration 4 .. objective value = 3.386238
# EBC finished in 4 iterations, with final objective value 3.3862
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.421210
# --> Running iteration 2 .. objective value = 3.363356
# --> Running iteration 3 .. objective value = 3.350270
# --> Running iteration 4 .. objective value = 3.348424
# EBC finished in 4 iterations, with final objective value 3.3484
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.482922
# --> Running iteration 2 .. objective value = 3.432981
# --> Running iteration 3 .. objective value = 3.416793
# --> Running iteration 4 .. objective value = 3.412884
# EBC finished in 4 iterations, with final objective value 3.4129
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.489010
# --> Running iteration 2 .. objective value = 3.432003
# --> Running iteration 3 .. objective value = 3.413898
# --> Running iteration 4 .. objective value = 3.407602
# EBC finished in 4 iterations, with final objective value 3.4076
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.477424
# --> Running iteration 2 .. objective value = 3.418674
# --> Running iteration 3 .. objective value = 3.405022
# --> Running iteration 4 .. objective value = 3.398932
# EBC finished in 4 iterations, with final objective value 3.3989
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.420156
# --> Running iteration 2 .. objective value = 3.380912
# --> Running iteration 3 .. objective value = 3.372648
# EBC finished in 3 iterations, with final objective value 3.3726
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.450709
# --> Running iteration 2 .. objective value = 3.415674
# --> Running iteration 3 .. objective value = 3.397274
# --> Running iteration 4 .. objective value = 3.390515
# EBC finished in 4 iterations, with final objective value 3.3905
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.436942
# --> Running iteration 2 .. objective value = 3.378955
# --> Running iteration 3 .. objective value = 3.360374
# --> Running iteration 4 .. objective value = 3.355171
# EBC finished in 4 iterations, with final objective value 3.3552
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.456677
# --> Running iteration 2 .. objective value = 3.394906
# --> Running iteration 3 .. objective value = 3.382881
# --> Running iteration 4 .. objective value = 3.379708
# EBC finished in 4 iterations, with final objective value 3.3797
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.426717
# --> Running iteration 2 .. objective value = 3.384859
# --> Running iteration 3 .. objective value = 3.375344
# EBC finished in 3 iterations, with final objective value 3.3753
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.506471
# --> Running iteration 2 .. objective value = 3.456788
# --> Running iteration 3 .. objective value = 3.443055
# --> Running iteration 4 .. objective value = 3.434907
# EBC finished in 4 iterations, with final objective value 3.4349
# Running EBC on a 2-d sparse matrix with size [3514, 1232] ...
# Randomly initializing clusters, with cluster number on each axis: [30, 125] ...
# --> Running iteration 1 .. objective value = 3.583342
# --> Running iteration 2 .. objective value = 3.531376
# --> Running iteration 3 .. objective value = 3.522453
# EBC finished in 3 iterations, with final objective value 3.5225
# [[1000   17    6 ...    9  105  170]
#  [  17 1000  290 ...   29   48   54]
#  [   6  290 1000 ...   56   64   21]
#  ...
#  [   9   29   56 ... 1000   25   24]
#  [ 105   48   64 ...   25 1000   23]
#  [ 170   54   21 ...   24   23 1000]]

# %%
#Getting the drug-gene pair label
with open("/content/ebc/resources/matrix-ebc-paper-dense.tsv", "r") as f:
        label = []
        for line in f:
            sl = line.split("\t")
            label.append(sl[0])
labels = list(dict.fromkeys(label))
print(labels)
# Out:
# ['(flavopiridol,nf-kappab)', '(tnf-r2,tnf-r1)', '(il-2,il-5)', '(il-11,il-10)', '(fgf-7,fgf-2)', '(clopidogrel,p-selectin)', '(fgf-7,fgf-1)', '(il-11,il-13)', '(propranolol,beta2)', '(isoflurane,caspase-3)', '(indomethacin,phospholipase)', '(anti-il-2,cd25)', '(zuclopenthixol,cyp2d6)', '(doxycycline,smad7)', '(il-2,il-1)', '(corticosteroids,leukotriene)', '(gliclazide,niddm)', '(tolbutamide,niddm)', '(dipyridamole,pde5)', '(geldanamycin,hsp90)', '(melatonin,bcl-2)', '(carbamates,faah)', '(pge2,pgd2)', '(losartan,urat1)', '(aldosterone,bmp-6)', '(gm-csf,il-13)', '(prostacyclin,cox-1)', '(astemizole,cyp2j2)', '(prostacyclin,cox-2)', '(gm-csf,il-15)', '(amiloride,kallikrein)', '(diphenhydramine,cyp2d6)', '(gm-csf,il-10)', '(valsartan,adiponectin)', '(forskolin,sf-1)', '(gm-csf,il-11)', '(il-11,gm-csf)', '(capecitabine,dlts)', '(pranlukast,cyslt1)', '(cetuximab,egfr)', '(gm-csf,il-18)', '(cysteamine,gastrin)', '(nadh,nad1)', '(nadh,nad3)', '(telmisartan,abca1)', '(abciximab,p-selectin)', '(capsaicin,ppargamma)', '(mitoxantrone,abcg2)', '(nadh,nad4)', '(vinblastine,mdr1)', '(glyburide,cyp2c9)', '(pgi2,pgis)', '(pge2,pges)', '(pitavastatin,nf-kappab)', '(glibenclamide,cftr)', '(genistein,ifn-gamma)', '(atra,mef2c)', '(cyclosporine,statin)', '(genistein,aromatase)', '(vardenafil,pde5)', '(lansoprazole,ho-1)', '(noradrenaline,endothelin-1)', '(il-2,nf-kappab)', '(arsenite,parp)', '(flutamide,lhrh)', '(d-amphetamine,amph)', '(lovastatin,cyp3a4)', '(topotecan,dlts)', '(suramin,vegf)', '(hydroquinone,dt-diaphorase)', '(dexamethasone,lactase)', '(tamoxifen,heparanase)', '(tamoxifen,her-2)', '(risperidone,cyp2d6)', '(staurosporine,hsp27)', '(atorvastatin,pcsk9)', '(promethazine,herg)', '(sildenafil,copd)', '(rituximab,bcl-2)', '(lovastatin,p21ras)', '(fenofibrate,ldlr)', '(pge2,pga1)', '(melatonin,gnrh)', '(cimetidine,cyp3a)', '(5-asa,inos)', '(rabeprazole,mucin)', '(dexamethasone,icam-1)', '(clenbuterol,beta2)', '(rosiglitazone,pepck)', '(oltipraz,nrf2)', '(doxazosin,alpha1)', '(cyclosporin,cox-2)', '(ddavp,p-selectin)', '(troglitazone,ppargamma)', '(curcumin,ho-1)', '(propofol,beta-endorphin)', '(dexamethasone,atrogin-1)', '(pge2,egr-1)', '(resveratrol,atf3)', '(indomethacin,crth2)', '(paclitaxel,tlr4)', '(pertuzumab,erbb2)', '(ethionamide,etha)', '(dexamethasone,cyp2e1)', '(gp120,ifn-gamma)', '(pge2,vegf)', '(imatinib,hoct1)', '(filgrastim,lenograstim)', '(lenograstim,filgrastim)', '(pioglitazone,ppar)', '(octreotide,vegf)', '(geldanamycin,hsp70)', '(corticosteroids,pprom)', '(paclitaxel,vegf)', '(epirubicin,filgrastim)', '(nebivolol,enos)', '(minocycline,fmr1)', '(il-2,csf-1)', '(gm-csf,flt3l)', '(losartan,cyp3a4)', '(modafinil,orexin)', '(succinylcholine,nachr)', '(coumarin,cyp3a4)', '(mifepristone,cox-1)', '(quetiapine,cyp3a4)', '(octreotide,calcitonin)', '(rapamycin,pten)', '(il-2,il2r)', '(tolbutamide,cyp2c)', '(imatinib,c-abl)', '(succinyldicholine,cholinesterase)', '(fluvastatin,nf-kappab)', '(naloxone,cgrp)', '(ng-monomethyl-l-arginine,inos)', '(cisplatin,caspase-9)', '(cisplatin,caspase-8)', '(resveratrol,mtor)', '(donepezil,igf-i)', '(hyaluronan,aggrecan)', '(nadh,sir2)', '(citalopram,sert)', '(il-1rn,il-1ra)', '(il-1ra,il-1rn)', '(estradiol,tebg)', '(capsaicin,cyclooxygenase-2)', '(alendronate,mmp-9)', '(flurbiprofen,cox-1)', '(flurbiprofen,cox-2)', '(imipramine,fmo1)', '(l-dopa,ghrh)', '(azathioprine,etanercept)', '(alendronate,mmp-2)', '(valganciclovir,pept1)', '(norepinephrine,gnrh)', '(spermine,ck-1)', '(cisplatin,caspase-3)', '(atorvastatin,oatp1b1)', '(cisplatin,caspase-2)', '(urokinase,cd87)', '(rapamycin,huntingtin)', '(arsenite,hsp27)', '(propofol,ho-1)', '(dexamethasone,parp)', '(progestogens,gnrh)', '(resveratrol,ampk)', '(ketoconazole,cyp51)', '(pge2,ccr7)', '(mirtazapine,bdnf)', '(clofibrate,pparalpha)', '(captopril,kallikrein)', '(topiramate,cgrp)', '(desferrioxamine,hif-1alpha)', '(g-csf,fmlp)', '(ketoconazole,cyp3a)', '(lapatinib,her1)', '(lapatinib,her2)', '(cisplatin,chk1)', '(bleomycin,gm-csf)', '(pge2,il-1 ...

# %%
df = pd.DataFrame(mat)
df.columns = labels
df.index = labels
df
# Out:
#                           (flavopiridol,nf-kappab)  ...  (zolmitriptan,5-ht1b)
# (flavopiridol,nf-kappab)                      1000  ...                    170
# (tnf-r2,tnf-r1)                                 17  ...                     54
# (il-2,il-5)                                      6  ...                     21
# (il-11,il-10)                                    3  ...                      7
# (fgf-7,fgf-2)                                    6  ...                      5
# ...                                            ...  ...                    ...
# (dexamethasone,nfkappab)                         3  ...                      2
# (propafenone,cyp1a2)                             3  ...                      2
# (cisplatin,brca1)                                9  ...                     24
# (ndga,nrf2)                                    105  ...                     23
# (zolmitriptan,5-ht1b)                          170  ...                   1000
#
# [3514 rows x 3514 columns]

# %%
df.to_csv('cluster.csv')
